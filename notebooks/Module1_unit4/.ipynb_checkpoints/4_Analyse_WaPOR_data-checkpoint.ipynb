# %% [markdown]
# # Analysing WaPOR data
#
# This notebook contains code snippet to analyse WaPOR data
# - [1. Calculate the average value of ROI](#1.-Calculate-the-average-value-of-ROI)
# - [2. Working with timeseries (pandas library)](#2.-Working-with-timeseries-(pandas-library))
# - [3. Raster calculation](#3.-Raster-calculation)
# - [4. Land-use analysis](#4.-Land-use-analysis)

# %% [markdown]
# ### Example
# For this exercise, we can make use of the user-defined functions we made in the previous exercise to read can write raster data.

# %%
import numpy as np
import gdal
import osr
import os
import matplotlib.pyplot as plt
import pandas as pd
import glob
import ogr

def GetGeoInfo(fh, subdataset = 0):
    """
    Substract metadata from a geotiff, HDF4 or netCDF file.
    
    Parameters
    ----------
    fh : str
        Filehandle to file to be scrutinized.
    subdataset : int, optional
        Layer to be used in case of HDF4 or netCDF format, default is 0.
        
    Returns
    -------
    driver : str
        Driver of the fh.
    NDV : float
        No-data-value of the fh.
    xsize : int
        Amount of pixels in x direction.
    ysize : int
        Amount of pixels in y direction.
    GeoT : list
        List with geotransform values.
    Projection : str
        Projection of fh.
    """
    SourceDS = gdal.Open(fh, gdal.GA_ReadOnly)
    Type = SourceDS.GetDriver().ShortName
    if Type == 'HDF4' or Type == 'netCDF':
        SourceDS = gdal.Open(SourceDS.GetSubDatasets()[subdataset][0])
    NDV = SourceDS.GetRasterBand(1).GetNoDataValue()
    xsize = SourceDS.RasterXSize
    ysize = SourceDS.RasterYSize
    GeoT = SourceDS.GetGeoTransform()
    Projection = osr.SpatialReference()
    Projection.ImportFromWkt(SourceDS.GetProjectionRef())
    driver = gdal.GetDriverByName(Type)
    return driver, NDV, xsize, ysize, GeoT, Projection

def OpenAsArray(fh, bandnumber = 1, dtype = 'float32', nan_values = False):
    """
    Open a map as an numpy array. 
    
    Parameters
    ----------
    fh: str
        Filehandle to map to open.
    bandnumber : int, optional 
        Band or layer to open as array, default is 1.
    dtype : str, optional
        Datatype of output array, default is 'float32'.
    nan_values : boolean, optional
        Convert he no-data-values into np.nan values, note that dtype needs to
        be a float if True. Default is False.
        
    Returns
    -------
    Array : ndarray
        Array with the pixel values.
    """
    datatypes = {"uint8": np.uint8, "int8": np.int8, "uint16": np.uint16,
                 "int16":  np.int16, "Int16":  np.int16, "uint32": np.uint32,
                 "int32": np.int32, "float32": np.float32, "float64": np.float64, 
                 "complex64": np.complex64, "complex128": np.complex128,
                "Int32": np.int32, "Float32": np.float32, "Float64": np.float64, 
                 "Complex64": np.complex64, "Complex128": np.complex128,}
    DataSet = gdal.Open(fh, gdal.GA_ReadOnly)
    Type = DataSet.GetDriver().ShortName
    if Type == 'HDF4':
        Subdataset = gdal.Open(DataSet.GetSubDatasets()[bandnumber][0])
        NDV = int(Subdataset.GetMetadata()['_FillValue'])
    else:
        Subdataset = DataSet.GetRasterBand(bandnumber)
        NDV = Subdataset.GetNoDataValue()
    Array = Subdataset.ReadAsArray().astype(datatypes[dtype])
    if nan_values:
        Array[Array == NDV] = np.nan
    return Array

def CreateGeoTiff(fh, Array, driver, NDV, xsize, ysize, GeoT, Projection, explicit = True, compress = None):
    """
    Creates a geotiff from a numpy array.
    
    Parameters
    ----------
    fh : str
        Filehandle for output.
    Array: ndarray
        Array to convert to geotiff.
    driver : str
        Driver of the fh.
    NDV : float
        No-data-value of the fh.
    xsize : int
        Amount of pixels in x direction.
    ysize : int
        Amount of pixels in y direction.
    GeoT : list
        List with geotransform values.
    Projection : str
        Projection of fh.    
    """
    datatypes = {"uint8": 1, "int8": 1, "uint16": 2, "int16": 3, "Int16": 3, "uint32": 4,
    "int32": 5, "float32": 6, "float64": 7, "complex64": 10, "complex128": 11,
    "Int32": 5, "Float32": 6, "Float64": 7, "Complex64": 10, "Complex128": 11,}
    if compress != None:
        DataSet = driver.Create(fh,xsize,ysize,1,datatypes[Array.dtype.name], ['COMPRESS={0}'.format(compress)])
    else:
        DataSet = driver.Create(fh,xsize,ysize,1,datatypes[Array.dtype.name])
    if NDV is None:
        NDV = -9999
    if explicit:
        Array[np.isnan(Array)] = NDV
    DataSet.GetRasterBand(1).SetNoDataValue(NDV)
    DataSet.SetGeoTransform(GeoT)
    DataSet.SetProjection(Projection.ExportToWkt())
    DataSet.GetRasterBand(1).WriteArray(Array)
    DataSet = None
    if "nt" not in Array.dtype.name:
        Array[Array == NDV] = np.nan


def MatchProjResNDV(source_file, target_fhs, output_dir, resample = 'near', 
                    dtype = 'float32', scale = None, ndv_to_zero = False):
    """
    Matches the projection, resolution and no-data-value of a list of target-files
    with a source-file and saves the new maps in output_dir.
    
    Parameters
    ----------
    source_file : str
        The file to match the projection, resolution and ndv with.
    target_fhs : list
        The files to be reprojected.
    output_dir : str
        Folder to store the output.
    resample : str, optional
        Resampling method to use, default is 'near' (nearest neighbour).
    dtype : str, optional
        Datatype of output, default is 'float32'.
    scale : int, optional
        Multiple all maps with this value, default is None.
    
    Returns
    -------
    output_files : ndarray 
        Filehandles of the created files.
    """
    dst_info=gdal.Info(gdal.Open(source_file),format='json')
    output_files = np.array([])
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    for target_file in target_fhs:
        folder, fn = os.path.split(target_file)
        src_info=gdal.Info(gdal.Open(target_file),format='json')
        output_file = os.path.join(output_dir, fn)
        gdal.Warp(output_file,target_file,format='GTiff',
                      srcSRS=src_info['coordinateSystem']['wkt'],
                      dstSRS=dst_info['coordinateSystem']['wkt'],
                      srcNodata=src_info['bands'][0]['noDataValue'],
                      dstNodata=dst_info['bands'][0]['noDataValue'],
                      width=dst_info['size'][0],
                      height=dst_info['size'][1],
                      outputBounds=(dst_info['cornerCoordinates']['lowerLeft'][0],
                                    dst_info['cornerCoordinates']['lowerLeft'][1],
                                    dst_info['cornerCoordinates']['upperRight'][0],
                                    dst_info['cornerCoordinates']['upperRight'][1]),
                      outputBoundsSRS=dst_info['coordinateSystem']['wkt'],
                      resampleAlg=resample)
        output_files = np.append(output_files, output_file)
        if not np.any([scale == 1.0, scale == None, scale == 1]):
            driver, NDV, xsize, ysize, GeoT, Projection = GetGeoInfo(output_file)
            DATA = OpenAsArray(output_file, nan_values = True) * scale
            CreateGeoTiff(output_file, DATA, driver, NDV, xsize, ysize, GeoT, Projection)
        if ndv_to_zero:
            driver, NDV, xsize, ysize, GeoT, Projection = GetGeoInfo(output_file)
            DATA = OpenAsArray(output_file, nan_values = False)
            DATA[DATA == NDV] = 0.0
            CreateGeoTiff(output_file, DATA, driver, NDV, xsize, ysize, GeoT, Projection)
    return output_files

def CliptoShp(input_fhs,output_folder,shp_fh,NDV=-9999):
    """
    Clip raster to boundary line of a shapefile
    
    Parameters
    ----------
    input_fhs : list
        The list of input raster files
    output_folder : str
        The path to folder where to save output rasters
    shp_fh : str
        Folder to store the output.
    NDV : float or int, optional
        No Data Value of output raster
        
    Returns
    -------
    output_fhs : list 
        Filehandles of the created files.
    """
    inDriver = ogr.GetDriverByName("ESRI Shapefile")
    inDataSource = inDriver.Open(shp_fh, 1)
    inLayer = inDataSource.GetLayer()    
    options = gdal.WarpOptions(cutlineDSName = shp_fh,
                               cutlineLayer = inLayer.GetName(),
                               cropToCutline = True, 
                               dstNodata=NDV
                               )
    output_fhs=[]
    for input_fh in input_fhs:
        output_fh=os.path.join(output_folder,os.path.basename(input_fh))
        sourceds = gdal.Warp(output_fh, input_fh, options = options)
        output_fhs.append(output_fh)
    return output_fhs

# %% [markdown]
# ## 1. Calculate the average value of ROI
# ### Example
# Calculate average precipitation in a ROI from a raster map (mm/month). First, check if the Precipitation map is warped to the same size with the Land-use map of ROI.
#
# *ET_folder* and *P_folder* are the paths to the Actual Evapotranspiration and Interception and Precipitation folder downloaded in notebook [03 Bulk download WaPOR data](03_Bulk_download_WaPOR_data.ipynb)

# %%
# Define ET and P folder:
ET_folder=r".\data\WAPOR.v2_monthly_L1_AETI_M"
P_folder=r".\data\WAPOR.v2_monthly_L1_PCP_M"
# Get list of files in folder:
P_fhs=glob.glob(os.path.join(P_folder,'*.tif'))
ET_fhs=glob.glob(os.path.join(ET_folder,'*.tif'))
# Get the path of the first file:
P_fh=P_fhs[0]
ET_fh=ET_fhs[0]
# Open the files as array
P=OpenAsArray(P_fh,nan_values=True)
ET=OpenAsArray(ET_fh,nan_values=True)
#print shape of arrays
print(P.shape)
print(ET.shape)

plt.imshow(P)
plt.show()
# Out:
# (111, 128)
# (2461, 2851)

# %% [markdown]
# The size of ET and P arrays are different because resolution of Level 1 Precipitation is 5km and that of ET is 250m. To warp all the precipitation rasters to the same resolution with Land cover classification raster, use the defined function *MatchProjResNDV*

# %%
output_folder=r'.\data\WAPOR.v2_monthly_L1_PCP_M_warped'
os.makedirs(output_folder)
P_fhs=MatchProjResNDV(ET_fh, P_fhs, output_folder)

# %% [markdown]
# Clip the ET and P rasters to the region of interest using a basin shapefile

# %%
shp_fh=r".\data\Awash_shapefile.shp"
ET_folder=r'.\data\WAPOR.v2_monthly_L1_AETI_M_clipped' #New ET folder
P_folder=r'.\data\WAPOR.v2_monthly_L1_PCP_M_clipped' # New P folder
os.makedirs(ET_folder) #create new ET folder
os.makedirs(P_folder) #create new P folder
ET_fhs=CliptoShp(ET_fhs,ET_folder,shp_fh) #clip all P rasters to shapefile
P_fhs=CliptoShp(P_fhs,P_folder,shp_fh) #clip all ET rasters to shapefile
# Out:
# ['.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0901M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0902M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0903M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0904M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0905M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0906M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0907M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0908M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0909M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0910M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0911M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_0912M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1001M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1002M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1003M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1004M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1005M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1006M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1007M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1008M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1009M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1010M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1011M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1012M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1101M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1102M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1103M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1104M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1105M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1106M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1107M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1108M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1109M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1110M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1111M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1112M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1201M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1202M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1203M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1204M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1205M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1206M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1207M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1208M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1209M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1210M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1211M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1212M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1301M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1302M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1303M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1304M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1305M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1306M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1307M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1308M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1309M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1310M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1311M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1312M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1401M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1402M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1403M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1404M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1405M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1406M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1407M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1408M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1409M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1410M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1411M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1412M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1501M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1502M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1503M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1504M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1505M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1506M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1507M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1508M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1509M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1510M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1511M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1512M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1601M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1602M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1603M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1604M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1605M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1606M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1607M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1608M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1609M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1610M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1611M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1612M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1701M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1702M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1703M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1704M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1705M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1706M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1707M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1708M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1709M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1710M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1711M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1712M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1801M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1802M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1803M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1804M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1805M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1806M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1807M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1808M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1809M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1810M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1811M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1812M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1901M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1902M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1903M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1904M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1905M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1906M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1907M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1908M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1909M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1910M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1911M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_1912M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_2001M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_2002M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_2003M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_2004M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_2005M.tif',
#  '.\\data\\WAPOR.v2_monthly_L1_PCP_M_clipped\\L1_PCP_2006M.tif']

# %% [markdown]
# Thus, we can get the average Precipitation of the whole area by *numpy.nanmean* which means calculate the average excluding pixels with nan values.

# %%
P=OpenAsArray(P_fhs[0],nan_values=True)
plt.imshow(P)
plt.show()
Average_P=np.nanmean(P)
print('Average Precipitation (mm/month): {0}'.format(Average_P))
# Out:
# Average Precipitation (mm/month): 25.643678665161133

# %% [markdown]
# ### Exercise (+)
# Get values of all monthly Precipitation maps and save the value in a Python *list* and plot average precipitation against time.
#
# **Hint**: You can make use of the file name to get *datetime* index. Look at example below.

# %%
import datetime

P_fh=r".\data\WAPOR.v2_monthly_L1_PCP_M_clipped\L1_PCP_0901M.tif"
filename=os.path.basename(P_fh)  
datestr=filename.split('.')[0].split('_')[-1]
print(datestr)
dyear=int('20'+datestr[0:2])
dmonth=int(datestr[2:4])
datetime.date(dyear,dmonth,1)
# Out:
# 0901M
# datetime.date(2009, 1, 1)

# %%
'''Write your code here'''

# %%
dates=[]
months=[]
years=[]
P_values=[]
for P_fh in P_fhs:
    filename=os.path.basename(P_fh)  
    datestr=filename.split('.')[0].split('_')[-1]
    dyear=int('20'+datestr[0:2]) #convert string to integer number
    dmonth=int(datestr[2:4])
    dates.append(datetime.date(dyear,dmonth,1))
    months.append(dmonth)
    years.append(dyear)
    #Calculate value
    P=OpenAsArray(P_fh,nan_values=True)    
    Average_P=np.nanmean(P)
    P_values.append(Average_P)

# %%
plt.plot(P_values)
plt.show()

# %% [markdown]
# We can decorate our graph with some extra code. For example

# %%
output_dir=r'.\data'
fig = plt.figure(figsize = (10,5))
plt.clf() #clear plot
plt.grid(b=True, which='Major', color='0.65',linestyle='--', zorder = 0) #Grid line
ax = plt.subplot(111)
ax.plot(dates, P_values, '-k') #Plot data as line
ax.fill_between(dates, P_values, color = '#6bb8cc') #Fill line area with color
ax.set_xlabel('Time') # X axis title
ax.set_ylabel('Precipitation [mm/month]') #Y axis title
ax.set_title('Precipitation, Awash Basin') #Figure title
fig.autofmt_xdate()
plt.savefig(os.path.join(output_dir, 'Precipitation_Awash_ts.png'))
plt.show()
plt.close(fig)

# %% [markdown]
# ## 2. Working with timeseries (pandas library)
# ### Example
# The lists created (*dates*, *months*, *years*, *P_values*) can be combined in a DataFrame object using *pandas.DataFrame*. This structure makes cleaning, transforming, manipulating and analyzing data easier.

# %%
P_df=pd.DataFrame({'date':dates,'month':months,'year':years,'value': P_values})
P_df.head()
# Out:
#          date  month  year      value
# 0  2009-01-01      1  2009  25.643679
# 1  2009-02-01      2  2009   7.820275
# 2  2009-03-01      3  2009  33.018497
# 3  2009-04-01      4  2009  36.029739
# 4  2009-05-01      5  2009  20.754398

# %% [markdown]
# For example, we can easily sum up precipitation of the monthly values into the yearly total precipitation using *groupby* of column *year* with method *sum*.

# %%
Year_total=P_df.groupby(['year']).sum()
Year_total['value']
# Out:
# year
# 2009    482.798503
# 2010    690.440463
# 2011    514.982476
# 2012    520.632244
# 2013    598.929884
# 2014    540.729045
# 2015    370.461408
# 2016    658.426705
# 2017    616.146138
# 2018    596.537416
# 2019    619.915906
# 2020    248.404049
# Name: value, dtype: float64

# %% [markdown]
# DataFrame columns can be converted to array and plotted easily. Below is the code to plot the total yearly precipitation. Discuss the interannual variation of precipitation in Awash.

# %%
fig = plt.figure(figsize = (10,5))
plt.clf() #clear plot
ax2 = plt.subplot(111)
ax2.grid(b=True, which='Major', color='0.65',linestyle='--', zorder = 0) #Grid line
ax2.bar(Year_total.index, Year_total['value'].values, 0.8, color = '#6bb8cc')
ax2.set_xlabel('Time [Year]')
ax2.set_xticks(Year_total.index)
ax2.set_ylabel('Precipitation [mm/year]')
ax2.set_title('Yearly Total Precipitation, Awash')
plt.savefig(os.path.join(output_dir, 'Precipitation_Awash_year.png'))
plt.show()
plt.close(fig)

# %% [markdown]
# ### Exercise (+)
# Calculate and plot the mean Precipitation of the calendar months. Discuss precipitation distribution in an average year.
#
# **Hint**
# Instead of using method *sum* in *groupby*, use *mean*

# %%
'''Write your code here'''

# %%
Month_avg=P_df.groupby(['month']).mean()
Month_avg['value']
fig = plt.figure(figsize = (10,5))
plt.clf() #clear plot
#subplot 1
ax1 = plt.subplot(111)
ax1.grid(b=True, which='Major', color='0.65',linestyle='--', zorder = 0) #Grid line
ax1.bar(Month_avg.index, Month_avg['value'].values, 0.8, color = '#6bb8cc')
ax1.set_xlabel('Time [month]')
monthname={1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
monthslabel=monthname.values()
ax1.set_xticks(Month_avg.index)
ax1.set_xticklabels(monthslabel)
ax1.set_ylabel('Precipitation [mm/month]')
ax1.set_title('Monthly average Precipitation, Awash')
plt.savefig(os.path.join(output_dir, 'Precipitation_Awash_month.png'))
plt.show()
plt.close(fig)

# %% [markdown]
# We can also save our dataframe as csv file using pandas.DataFrame method *to_csv* for later use in other analysis.

# %%
Month_max=P_df.groupby(['month']).max()
Month_min=P_df.groupby(['month']).min()
Month_med=P_df.groupby(['month']).median()
Month_std=P_df.groupby(['month']).std()

Month_stat=pd.DataFrame({'month': Month_avg.index,'Mean':Month_avg['value'].values,
                        'Max':Month_max['value'].values, 'Min':Month_min['value'].values,
                        'Median':Month_med['value'].values,'Std':Month_std['value'].values})
print(Month_stat)
Month_stat.to_csv(r'.\data\P_month_stats.csv',sep=';')
# Out:
#     month        Mean         Max         Min      Median        Std
# 0       1    8.798684   25.643679    0.000000    7.256673   6.208609
# 1       2   15.874421   46.456440    3.876169   10.652762  12.904095
# 2       3   38.935282   75.082008   13.794790   31.501373  19.933482
# 3       4   63.718485  136.544098   19.810299   63.129070  34.335621
# 4       5   49.589662   84.846054   20.754398   46.123030  18.989558
# 5       6   29.268059   45.118271   14.301813   29.923598   8.120334
# 6       7  115.839360  152.394821   38.821857  115.309631  33.753683
# 7       8  141.685741  192.506104  111.081451  140.312897  25.794599
# 8       9   64.809218   97.786369   33.969002   61.601212  21.947757
# 9      10   22.462830   54.127079    4.166919    8.384825  19.469204
# 10     11   13.706721   34.339146    3.421068   13.430651   8.722320
# 11     12    3.695141   10.138801    1.057021    2.460312   3.169943

# %% [markdown]
# ## 3. Raster calculation
# ### Example: P - ET
# First, we need to get the file handler of the rasters of the same date that have been matched projection, size and resolution. We can make use of the time format in file name as below.

# %%
start_date='2009-01-01'
end_date='2009-12-31'
dates=pd.date_range(start_date,end_date,freq='M') #create a date range from start_date and end_date

P_path=r'.\data\WAPOR.v2_monthly_L1_PCP_M_clipped\L1_PCP_{:2}{:02d}M.tif' #template string to format
ET_path=r'.\data\WAPOR.v2_monthly_L1_AETI_M_clipped\L1_AETI_{:2}{:02d}M.tif' #template string to format

date=dates[0] #get the first date in the date range
print(date)
P_fh=P_path.format(str(date.year)[2:],date.month) #format filename using the selected date
ET_fh=ET_path.format(str(date.year)[2:],date.month) #format filename using the selected date
print(P_fh)
print(ET_fh)
# Out:
# 2009-01-31 00:00:00
# .\data\WAPOR.v2_monthly_L1_PCP_M_clipped\L1_PCP_0901M.tif
# .\data\WAPOR.v2_monthly_L1_AETI_M_clipped\L1_AETI_0901M.tif

# %% [markdown]
# The difference between Precipitation and Total EvapoTranspiration (P-ET) of the pixel can indicate whether the pixel is sink or source of water. When P-ET>0, water is generated in the pixel area. When P-ET< 0, water is more depleted in the pixel area. For example, below is how we can calculate P-ET for one month (January 2009). Notice where P-ET is negative and positive.

# %%
P=OpenAsArray(P_fh,nan_values=True)
ET=OpenAsArray(ET_fh,nan_values=True)
P_ET=P-ET
plt.imshow(P_ET)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Exercise (++)
# Calculate annual P - ET of a chosen year in Awash Basin. Discuss the source (P-ET > 0) and sink (P-ET < 0) of water and compare your year result with others.
#
# **Hint**: You can calculate total annual map of P and ET from monthly maps then substract annual ET from annual P map or calculate difference each month then sum up.
# Questions:
# - Would the two method give same results? Why?
# - Which method is faster? Why?

# %%
'''Write your code here'''

# %% [markdown]
# ## 4. Land-use analysis
# ### Example:
# We will first clip the WaPOR LCC rasters downloaded from [03 Bulk download WaPOR data](03_Bulk_download_WaPOR_data.ipynb) then get the list of unique Land Cover classes from WaPOR Land Cover Classification rasters.

# %%
shp_fh=r".\data\Awash_shapefile.shp"
LCC_folder=r'.\data\WAPOR.v2_yearly_L1_LCC_A'
LCC_fhs=glob.glob(os.path.join(LCC_folder,'*.tif')) #get list of LCC rasters
output_folder=r'.\data\WAPOR.v2_yearly_L1_LCC_A_clipped' # New LCC folder
os.makedirs(output_folder) #create new P folder
LCC_fhs=CliptoShp(LCC_fhs,output_folder,shp_fh) #clip all LCC rasters to shapefile

# %%
LU_fh=r".\data\WAPOR.v2_yearly_L1_LCC_A_clipped\L1_LCC_09.tif"
LU=OpenAsArray(LU_fh,nan_values=True)
LU_values=np.unique(LU[~np.isnan(LU)])
LU_codes=list(LU_values)
print(LU_codes)
# Out:
# [20.0, 30.0, 41.0, 42.0, 43.0, 50.0, 60.0, 80.0, 90.0, 112.0, 114.0, 116.0, 124.0, 126.0]

# %% [markdown]
# For example, to get ET value per a land-use class (Water bodies), we can mask the ET array using LCC array

# %%
code=80 #Water bodies

mask=np.where(LU==code,0,1)
in_fh=r".\data\WAPOR.v2_monthly_L1_AETI_M_clipped\L1_AETI_0901M.tif"
var=OpenAsArray(in_fh,nan_values=True)

import numpy.ma as ma
masked_map=ma.masked_array(var,mask)
plt.imshow(masked_map)
plt.colorbar()
plt.show()

# %% [markdown]
# After that, we can calculate average ET of a the water bodies land-use class using the masked array

# %%
average=np.nanmean(masked_map)
print('Landuse class {0} Average: {1}'.format(code,average))
# Out:
# Landuse class 80 Average: 104.69696044921875

# %% [markdown]
# ### Exercise (++)
# Calculate a table of annual average ET, E,T, I and P-ET of all land-use class.
# Discuss which land-use class is sink and which is source.
# Compare Evaporation in the main classes: Forest, Shrubland, Grassland, Water bodies, Bare land, Rainfed crops, Irrigated crops.
#
# For the table of Land Cover Classification, see the WaPOR catalog https://wapor.apps.fao.org/catalog/WAPOR_2/1/L1_LCC_A
#
# **Hints**: You can use a for-loop over all land-use classes in the land-use map.

# %%
'''Write your code here'''

# %%
averages=[]
for code in LU_codes:
    mask=np.where(LU==code,0,1)
    masked_map=ma.masked_array(var,mask)
    averages.append(np.nanmean(masked_map))
LU_avg=pd.DataFrame({'LU code':LU_codes,'Average Value': averages})
LU_avg
# Out:
#     LU code  Average Value
# 0      20.0      37.537735
# 1      30.0      17.037479
# 2      41.0      47.709606
# 3      42.0      78.880722
# 4      43.0       6.646875
# 5      50.0      25.989452
# 6      60.0       8.477416
# 7      80.0     104.696960
# 8      90.0     100.415855
# 9     112.0     118.877800
# 10    114.0      93.828674
# 11    116.0     106.359238
# 12    124.0      71.121025
# 13    126.0      62.914829
