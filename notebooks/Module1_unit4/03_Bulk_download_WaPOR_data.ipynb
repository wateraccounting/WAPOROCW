# %% [markdown]
# # Bulk-download WaPOR data
#
# In this notebook, we will use local Python module to automate the steps to read dataset metadata, requset download url, download raster dataset, pre-process raster dataset using information from metadata (such as conversion factor, unit).
#
# Run the code cell below to import packages and modules needed. You will be asked to provide WaPOR API token, the *WaPOR* module will remember your token and save it to the module folder. If you want to use a new API token, you have to delete this file **'modules\WaPOR\wapor_api_token.pickle'**

# %%
import os
import glob
import sys
import shapefile             
import matplotlib.pyplot as plt 

folder=r"..\..\modules"
sys.path.append(folder) #add folder with local modules to system paths
import WaPOR #import local module 'WaPOR'
WaPOR.API.version=2 #select WaPOR version
WaPOR.API.getCatalog()
# Out:
# Loading WaPOR catalog...
#                                         additionalInfo  \
# 0    {'format': 'Raster Dataset', 'unit': 'kg/m³ is...
# 1    {'format': 'Raster Dataset', 'unit': 'kg/m³ is...
# 2    {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 3    {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 4    {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 5    {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 6    {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 7    {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 8    {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 9    {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 10   {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 11   {'format': 'Raster Dataset', 'unit': 'g/m²', '...
# 12   {'format': 'Raster Dataset', 'unit': 'kg/ha', ...
# 13   {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 14   {'format': 'Raster Dataset', 'unit': 'mm (1mm=...
# 15   {'format': 'Raster Dataset', 'unit': 'mm (1mm=...
# 16   {'format': 'Raster Dataset', 'unit': 'mm (1mm=...
# 17   {'format': 'Raster Dataset', 'unit': 'mm (1mm=...
# 18   {'format': 'Raster Dataset', 'unit': 'mm (1mm=...
# 19   {'format': 'Raster Dataset', 'unit': 'mm (1mm=...
# 20   {'format': 'Raster Dataset', 'unit': 'mm (1mm=...
# 21   {'format': 'Raster Dataset', 'unit': 'mm (1mm=...
# 22   {'format': 'Raster Dataset', 'unit': 'd', 'dat...
# 23   {'format': 'Raster Dataset', 'unit': 'day', 'd...
# 24   {'format': 'Raster Dataset', 'unit': '%', 'dat...
# 25   {'format': 'Raster Dataset', 'unit': 'kg/m³', ...
# 26   {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 27   {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 28   {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# 29   {'format': 'Raster Dataset', 'unit': 'mm', 'da...
# ..                                                 ...
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
#
#                                                caption                code  \
# 0                     Gross Biomass Water Productivity           L1_GBWP_A
# 1                       Net Biomass Water Productivity           L1_NBWP_A
# 2    Actual EvapoTranspiration and Interception (An...           L1_AETI_A
# 3    Actual EvapoTranspiration and Interception (Mo...           L1_AETI_M
# 4    Actual EvapoTranspiration and Interception (De...           L1_AETI_D
# 5                               Transpiration (Annual)              L1_T_A
# 6                                 Evaporation (Annual)              L1_E_A
# 7                                Interception (Annual)              L1_I_A
# 8                              Transpiration (Dekadal)              L1_T_D
# 9                                Evaporation (Dekadal)              L1_E_D
# 10                              Interception (Dekadal)              L1_I_D
# 11                              Net Primary Production            L1_NPP_D
# 12                   Total Biomass Production (Annual)            L1_TBP_A
# 13                           Land Cover Classification            L1_LCC_A
# 14               Reference EvapoTranspiration (Annual)            L1_RET_A
# 15                              Precipitation (Annual)            L1_PCP_A
# 16              Reference EvapoTranspiration (Monthly)            L1_RET_M
# 17                             Precipitation (Monthly)            L1_PCP_M
# 18              Reference EvapoTranspiration (Dekadal)            L1_RET_D
# 19                             Precipitation (Dekadal)            L1_PCP_D
# 20                Reference EvapoTranspiration (Daily)            L1_RET_E
# 21                               Precipitation (Daily)            L1_PCP_E
# 22   Quality of Normalized Difference Vegetation In...      L1_QUAL_NDVI_D
# 23          Quality Land Surface Temperature (Dekadal)       L1_QUAL_LST_D
# 24   Quality of Normalized Difference Vegetation In...     L1_QUAL_NDVI_LT
# 25         Gross Biomass Water Productivity (Seasonal)           L2_GBWP_S
# 26   Actual EvapoTranspiration and Interception (An...           L2_AETI_A
# 27   Actual EvapoTranspiration and Interception (Mo...           L2_AETI_M
# 28   Actual EvapoTranspiration and Interception (De...           L2_AETI_D
# 29                              Transpiration (Annual)              L2_T_A
# ..                                                 ...                 ...
# 164  Actual EvapoTranspiration and Interception (An...       L2_BAS_AETI_A
# 165  Actual EvapoTranspiration and Interception (An...       L2_CTY_AETI_A
# 166  Actual EvapoTranspiration and Interception (Mo...       L2_BAS_AETI_M
# 167  Actual EvapoTranspiration and Interception (Mo...       L2_CTY_AETI_M
# 168  Actual EvapoTranspiration and Interception (De...       L2_BAS_AETI_D
# 169  Actual EvapoTranspiration and Interception (De...       L2_CTY_AETI_D
# 170           Transpiration (Annual, clipped by basin)          L2_BAS_T_A
# 171         Transpiration (Annual, clipped by country)          L2_CTY_T_A
# 172             Evaporation (Annual, clipped by basin)          L2_BAS_E_A
# 173           Evaporation (Annual, clipped by country)          L2_CTY_E_A
# 174            Interception (Annual, clipped by basin)          L2_BAS_I_A
# 175          Interception (Annual, clipped by country)          L2_CTY_I_A
# 176          Transpiration (Dekadal, clipped by basin)          L2_BAS_T_D
# 177        Transpiration (Dekadal, clipped by country)          L2_CTY_T_D
# 178            Evaporation (Dekadal, clipped by basin)          L2_BAS_E_D
# 179          Evaporation (Dekadal, clipped by country)          L2_CTY_E_D
# 180  Net Primary Production (Dekadal, clipped by ba...        L2_BAS_NPP_D
# 181           Interception (Dekadal, clipped by basin)          L2_BAS_I_D
# 182         Interception (Dekadal, clipped by country)          L2_CTY_I_D
# 183  Net Primary Production (Dekadal, clipped by co...        L2_CTY_NPP_D
# 184  Total Biomass Production (Seasonal, clipped by...        L2_BAS_TBP_S
# 185           Phenology (Seasonal, clipped by country)        L2_CTY_PHE_S
# 186  Total Biomass Production (Seasonal, clipped by...        L2_CTY_TBP_S
# 187  Land Cover Classification (Annual, clipped by ...        L2_BAS_LCC_A
# 188  Land Cover Classification (Annual, clipped by ...        L2_CTY_LCC_A
# 189             Phenology (Seasonal, clipped by basin)        L2_BAS_PHE_S
# 190  Quality of Normalized Difference Vegetation In...  L2_BAS_QUAL_NDVI_D
# 191  Quality of Normalized Difference Vegetation In...  L2_CTY_QUAL_NDVI_D
# 192  Quality Land Surface Temperature (Dekadal, cli...   L2_BAS_QUAL_LST_D
# 193  Quality Land Surface Temperature (Dekadal, cli...   L2_CTY_QUAL_LST_D
#
#     dataType                                        description  hidden  \
# 0     RASTER  The annual Gross Biomass Water Productivity ex...   False
# 1     RASTER  The annual Net Biomass Water Productivity expr...   False
# 2     RASTER  The actual EvapoTranspiration and Interception...   False
# 3     RASTER  The actual EvapoTranspiration and Interception...   False
# 4     RASTER  The actual EvapoTranspiration and Interception...   False
# 5     RASTER  The Transpiration (T) data component is the ac...   False
# 6     RASTER  The Evaporation (E) data component is the actu...   False
# 7     RASTER  Interception is the process where rainfall is ...   False
# 8     RASTER  The transpiration (T) data component (dekadal,...   False
# 9     RASTER  The Evaporation (E) data component (dekadal, i...   False
# 10    RASTER  The Interception (I) data component (dekadal, ...   False
# 11    RASTER  Net Primary Production (NPP) is a fundamental ...   False
# 12    RASTER  The annual Total Biomass Production expresses ...   False
# 13    RASTER  This land cover dataset at continental scale i...   False
# 14    RASTER  Reference EvapoTranspiration (RET) is defined ...   False
# 15    RASTER  Precipitation data is delivered on a daily bas...   False
# 16    RASTER  Reference EvapoTranspiration (RET) is defined ...   False
# 17    RASTER  Precipitation data is delivered on a daily bas...   False
# 18    RASTER  Reference EvapoTranspiration (RET) is defined ...   False
# 19    RASTER  Precipitation data is delivered on a daily bas...   False
# 20    RASTER  Reference EvapoTranspiration (RET) is defined ...   False
# 21    RASTER  Precipitation data is delivered on a daily bas...   False
# 22    RASTER  The layer gives an indication of the quality o...   False
# 23    RASTER  The quality layer gives an indication on the q...   False
# 24    RASTER  The long-term NDVI quality layer is produced a...   False
# 25    RASTER  The seasonal Gross Biomass Water Productivity ...   False
# 26    RASTER  The actual EvapoTranspiration and Interception...   False
# 27    RASTER  The actual EvapoTranspiration and Interception...   False
# 28    RASTER  The actual EvapoTranspiration and Interception...   False
# 29    RASTER  The Transpiration (T) data component is the ac...   False
# ..       ...                                                ...     ...
# 164   RASTER  This is a system dataset, used to let the down...    True
# 165   RASTER  This is a system dataset, used to let the down...    True
# 166   RASTER  This is a system dataset, used to let the down...    True
# 167   RASTER  This is a system dataset, used to let the down...    True
# 168   RASTER  This is a system dataset, used to let the down...    True
# 169   RASTER  This is a system dataset, used to let the down...    True
# 170   RASTER  This is a system dataset, used to let the down...    True
# 171   RASTER  This is a system dataset, used to let the down...    True
# 172   RASTER  This is a system dataset, used to let the down...    True
# 173   RASTER  This is a system dataset, used to let the down...    True
# 174   RASTER  This is a system dataset, used to let the down...    True
# 175   RASTER  This is a system dataset, used to let the down...    True
# 176   RASTER  This is a system dataset, used to let the down...    True
# 177   RASTER  This is a system dataset, used to let the down...    True
# 178   RASTER  This is a system dataset, used to let the down...    True
# 179   RASTER  This is a system dataset, used to let the down...    True
# 180   RASTER  This is a system dataset, used to let the down...    True
# 181   RASTER  This is a system dataset, used to let the down...    True
# 182   RASTER  This is a system dataset, used to let the down...    True
# 183   RASTER  This is a system dataset, used to let the down...    True
# 184   RASTER  This is a system dataset, used to let the down...    True
# 185   RASTER  This is a system dataset, used to let the down...    True
# 186   RASTER  This is a system dataset, used to let the down...    True
# 187   RASTER  This is a system dataset, used to let the down...    True
# 188   RASTER  This is a system dataset, used to let the down...    True
# 189   RASTER  This is a system dataset, used to let the down...    True
# 190   RASTER  This is a system dataset, used to let the down...    True
# 191   RASTER  This is a system dataset, used to let the down...    True
# 192   RASTER  This is a system dataset, used to let the down...    True
# 193   RASTER  This is a system dataset, used to let the down...    True
#
#      index                                              links  \
# 0      101  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 1      102  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 2      103  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 3      104  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 4      105  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 5      106  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 6      107  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 7      108  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 8      109  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 9      110  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 10     111  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 11     112  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 12     113  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 13     114  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 14     115  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 15     116  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 16     117  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 17     118  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 18     119  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 19     120  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 20     121  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 21     122  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 22     123  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 23     124  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 24     124  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 25     201  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 26     203  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 27     204  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 28     205  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 29     206  [{'rel': 'self', 'href': 'https://io.apps.fao....
# ..     ...                                                ...
# 164   4031  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 165   4032  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 166   4041  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 167   4042  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 168   4051  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 169   4052  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 170   4061  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 171   4062  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 172   4071  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 173   4072  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 174   4081  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 175   4082  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 176   4091  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 177   4092  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 178   4101  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 179   4102  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 180   4111  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 181   4111  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 182   4112  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 183   4112  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 184   4131  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 185   4132  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 186   4132  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 187   4141  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 188   4142  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 189   4151  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 190   4161  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 191   4162  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 192   4171  [{'rel': 'self', 'href': 'https://io.apps.fao....
# 193   4172  [{'rel': 'self', 'href': 'https://io.apps.fao....
#
#                                              operation  \
# 0    {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 1    {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 2    {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 3    {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 4    {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 5    {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 6    {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 7    {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 8    {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 9    {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 10   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 11   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 12   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 13   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 14   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 15   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 16   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 17   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 18   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 19   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 20   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 21   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 22   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 23   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 24        {'pixelTimeSeries': True, 'areaStats': True}
# 25   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 26   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 27   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 28   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# 29   {'pixelTimeSeries': True, 'areaStatsTimeSeries...
# ..                                                 ...
# 164  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 165  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 166  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 167  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 168  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 169  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 170  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 171  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 172  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 173  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 174  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 175  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 176  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 177  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 178  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 179  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 180  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 181  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 182  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 183  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 184  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 185  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 186  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 187  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 188  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 189  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 190  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 191  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 192  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
# 193  {'pixelTimeSeries': False, 'areaStatsTimeSerie...
#
#                                                   tags workspaceCode  \
# 0    [{'name': 'L1', 'index': 1, 'context': 'LEVELS...       WAPOR_2
# 1    [{'name': 'L1', 'index': 2, 'context': 'LEVELS...       WAPOR_2
# 2    [{'name': 'L1', 'index': 3, 'context': 'LEVELS...       WAPOR_2
# 3    [{'name': 'L1', 'index': 4, 'context': 'LEVELS...       WAPOR_2
# 4    [{'name': 'L1', 'index': 5, 'context': 'LEVELS...       WAPOR_2
# 5    [{'name': 'L1', 'index': 6, 'context': 'LEVELS...       WAPOR_2
# 6    [{'name': 'L1', 'index': 7, 'context': 'LEVELS...       WAPOR_2
# 7    [{'name': 'L1', 'index': 8, 'context': 'LEVELS...       WAPOR_2
# 8    [{'name': 'L1', 'index': 9, 'context': 'LEVELS...       WAPOR_2
# 9    [{'name': 'L1', 'index': 10, 'context': 'LEVEL...       WAPOR_2
# 10   [{'name': 'L1', 'index': 11, 'context': 'LEVEL...       WAPOR_2
# 11   [{'name': 'L1', 'index': 12, 'context': 'LEVEL...       WAPOR_2
# 12   [{'name': 'L1', 'index': 13, 'context': 'LEVEL...       WAPOR_2
# 13   [{'name': 'L1', 'index': 14, 'context': 'LEVEL...       WAPOR_2
# 14   [{'name': 'L1', 'index': 15, 'context': 'LEVEL...       WAPOR_2
# 15   [{'name': 'L1', 'index': 16, 'context': 'LEVEL...       WAPOR_2
# 16   [{'name': 'L1', 'index': 17, 'context': 'LEVEL...       WAPOR_2
# 17   [{'name': 'L1', 'index': 18, 'context': 'LEVEL...       WAPOR_2
# 18   [{'name': 'L1', 'index': 19, 'context': 'LEVEL...       WAPOR_2
# 19   [{'name': 'L1', 'index': 20, 'context': 'LEVEL...       WAPOR_2
# 20   [{'name': 'L1', 'index': 21, 'context': 'LEVEL...       WAPOR_2
# 21   [{'name': 'L1', 'index': 22, 'context': 'LEVEL...       WAPOR_2
# 22   [{'name': 'L1', 'index': 23, 'context': 'LEVEL...       WAPOR_2
# 23   [{'name': 'L1', 'index': 24, 'context': 'LEVEL...       WAPOR_2
# 24   [{'name': 'L1', 'index': 24, 'context': 'LEVEL...       WAPOR_2
# 25   [{'name': 'L2', 'index': 1, 'context': 'LEVELS...       WAPOR_2
# 26   [{'name': 'L2', 'index': 3, 'context': 'LEVELS...       WAPOR_2
# 27   [{'name': 'L2', 'index': 4, 'context': 'LEVELS...       WAPOR_2
# 28   [{'name': 'L2', 'index': 5, 'context': 'LEVELS...       WAPOR_2
# 29   [{'name': 'L2', 'index': 6, 'context': 'LEVELS...       WAPOR_2
# ..                                                 ...           ...
# 164                                                NaN       WAPOR_2
# 165                                                NaN       WAPOR_2
# 166                                                NaN       WAPOR_2
# 167                                                NaN       WAPOR_2
# 168                                                NaN       WAPOR_2
# 169                                                NaN       WAPOR_2
# 170                                                NaN       WAPOR_2
# 171                                                NaN       WAPOR_2
# 172                                                NaN       WAPOR_2
# 173                                                NaN       WAPOR_2
# 174                                                NaN       WAPOR_2
# 175                                                NaN       WAPOR_2
# 176                                                NaN       WAPOR_2
# 177                                                NaN       WAPOR_2
# 178                                                NaN       WAPOR_2
# 179                                                NaN       WAPOR_2
# 180                                                NaN       WAPOR_2
# 181                                                NaN       WAPOR_2
# 182                                                NaN       WAPOR_2
# 183                                                NaN       WAPOR_2
# 184                                                NaN       WAPOR_2
# 185                                                NaN       WAPOR_2
# 186                                                NaN       WAPOR_2
# 187                                                NaN       WAPOR_2
# 188                                                NaN       WAPOR_2
# 189                                                NaN       WAPOR_2
# 190                                                NaN       WAPOR_2
# 191                                                NaN       WAPOR_2
# 192                                                NaN       WAPOR_2
# 193                                                NaN       WAPOR_2
#
#                                                measure  \
# 0    {'code': 'WPR', 'caption': 'Water Productivity...
# 1    {'code': 'WPR', 'caption': 'Water Productivity...
# 2    {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 3    {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 4    {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 5    {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 6    {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 7    {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 8    {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 9    {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 10   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 11   {'code': 'NPP', 'caption': 'Net Primary Produc...
# 12   {'code': 'LPR', 'caption': 'Land Productivity'...
# 13   {'code': 'LCC', 'caption': 'Land Cover Classif...
# 14   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 15   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 16   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 17   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 18   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 19   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 20   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 21   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 22   {'code': 'N_DAYS', 'caption': 'Number of Days'...
# 23   {'code': 'N_DAYS', 'caption': 'Number of Days'...
# 24   {'code': 'ACC', 'caption': 'Accuracy', 'descri...
# 25   {'code': 'WPR', 'caption': 'Water Productivity...
# 26   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 27   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 28   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 29   {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# ..                                                 ...
# 164  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 165  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 166  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 167  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 168  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 169  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 170  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 171  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 172  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 173  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 174  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 175  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 176  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 177  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 178  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 179  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 180  {'code': 'NPP', 'caption': 'Net Primary Produc...
# 181  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 182  {'code': 'WATER_MM', 'caption': 'Amount of Wat...
# 183  {'code': 'NPP', 'caption': 'Net Primary Produc...
# 184  {'code': 'LPR_S', 'caption': 'Land Productivit...
# 185  {'code': 'PHE', 'caption': 'Phenology', 'descr...
# 186  {'code': 'LPR_S', 'caption': 'Land Productivit...
# 187  {'code': 'LCC', 'caption': 'Land Cover Classif...
# 188  {'code': 'LCC', 'caption': 'Land Cover Classif...
# 189  {'code': 'PHE', 'caption': 'Phenology', 'descr...
# 190  {'code': 'N_DAYS', 'caption': 'Number of Days'...
# 191  {'code': 'N_DAYS', 'caption': 'Number of Days'...
# 192  {'code': 'N_DAYS', 'caption': 'Number of Days'...
# 193  {'code': 'N_DAYS', 'caption': 'Number of Days'...
#
#                                              dimension
# 0    [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 1    [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 2    [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 3    [{'code': 'MONTH', 'caption': 'Month', 'worksp...
# 4    [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 5    [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 6    [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 7    [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 8    [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 9    [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 10   [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 11   [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 12   [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 13   [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 14   [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 15   [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 16   [{'code': 'MONTH', 'caption': 'Month', 'worksp...
# 17   [{'code': 'MONTH', 'caption': 'Month', 'worksp...
# 18   [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 19   [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 20   [{'code': 'DAY', 'caption': 'Day', 'workspaceC...
# 21   [{'code': 'DAY', 'caption': 'Day', 'workspaceC...
# 22   [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 23   [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 24   [{'code': 'LTP', 'caption': 'Long Term', 'desc...
# 25   [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 26   [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 27   [{'code': 'MONTH', 'caption': 'Month', 'worksp...
# 28   [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 29   [{'code': 'YEAR', 'caption': 'Year', 'descript...
# ..                                                 ...
# 164  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 165  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 166  [{'code': 'MONTH', 'caption': 'Month', 'worksp...
# 167  [{'code': 'MONTH', 'caption': 'Month', 'worksp...
# 168  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 169  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 170  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 171  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 172  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 173  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 174  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 175  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 176  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 177  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 178  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 179  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 180  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 181  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 182  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 183  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 184  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 185  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 186  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 187  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 188  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 189  [{'code': 'YEAR', 'caption': 'Year', 'descript...
# 190  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 191  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 192  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
# 193  [{'code': 'DEKAD', 'caption': 'Dekad (10-Days ...
#
# [194 rows x 13 columns]

# %% [markdown]
# ## Set download extent and output folder
#
# Change xmin, ymin, xmax, ymax values to the download extent.
# If needed, change *output_dir* path to the folder where you want to save data.

# %%
#define extent to download from a shapefile:
shape_fh=r".\data\Awash_shapefile.shp"
shape=shapefile.Reader(shape_fh)
xmin,ymin,xmax,ymax=shape.bbox

#define extent to download by coordinates:
# xmin,ymin,xmax,ymax=(32.65692516077674,-25.16412729789142,32.90420244933813,-25.01450956754679)

output_dir=r'.\data' # folder to save data

# %% [markdown]
# ## Datacube code
#
# Select the code of the dataset to download from this table.
#
# | code        | Name          |
# | :---------: |:-------------:|
# | LCC | Land Cover Classification      |
# | PCP      | Precipitation      |
# | RET      | Reference Evapotranspiration      |
# | NPP      | Net Primary Production |
# | AETI      | Actual Evapotranspiration and Interception |
# | E | Evaporation      |
# | I | Interception      |
# | T | Transpiration      |
#
# Use the selected data code instead of **RET** for the **data** parameter value in the code cells below.

# %% [markdown]
# ## Download dekadal data

# %%
WaPOR.download_dekadal(output_dir, 
                       data='RET',
                       Startdate='2009-01-01', 
                       Enddate='2009-12-31',
                       latlim=[ymin-0.5, ymax+0.5], 
                       lonlim=[xmin-0.5, xmax+0.5],
                       level=1, 
                       )
# Out:
# Download WaPOR Level 1 dekadal RET data for the period 2009-01-01 till 2009-12-31
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# '.\\data\\WAPOR.v2_dekadal_L1_RET_D'

# %% [markdown]
# ## Download monthly data

# %%
WaPOR.download_monthly(output_dir, 
                       data='RET',
                       Startdate='2009-01-01', 
                       Enddate='2009-12-31', 
                       latlim=[ymin-0.5, ymax+0.5], 
                       lonlim=[xmin-0.5, xmax+0.5],
                       level=1, 
                       )
# Out:
# Download WaPOR Level 1 monthly RET data for the period 2009-01-01 till 2009-12-31
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# '.\\data\\WAPOR.v2_monthly_L1_RET_M'

# %% [markdown]
# ## Download yearly data

# %%
WaPOR.download_yearly(output_dir, 
                       data='RET',
                       Startdate='2009-01-01', 
                       Enddate='2009-12-31',
                       latlim=[ymin-0.5, ymax+0.5], 
                       lonlim=[xmin-0.5, xmax+0.5],
                       level=1, 
                       )
# Out:
# Download WaPOR Level 1 yearly RET data for the period 2009-01-01 till 2009-12-31
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# '.\\data\\WAPOR.v2_yearly_L1_RET_A'

# %% [markdown]
# # Exercise
#
# Download monthly Precipitation, Actual Evapotranspiration and Interception, and yearly Land cover classification from 2009 to 2010 for the area bounded by the shapefile ".\data\Awash_shapefile.shp"

# %%
PCP_dir=WaPOR.download_monthly(output_dir, 
                       data='PCP',
                       Startdate='2009-01-01', 
                       Enddate='20010-12-31', 
                       latlim=[ymin-0.5, ymax+0.5], 
                       lonlim=[xmin-0.5, xmax+0.5],
                       level=1, 
                       )

AETI_dir=WaPOR.download_monthly(output_dir, 
                       data='AETI',
                       Startdate='2009-01-01', 
                       Enddate='2010-12-31', 
                       latlim=[ymin-0.5, ymax+0.5], 
                       lonlim=[xmin-0.5, xmax+0.5],
                       level=1, 
                       )

LCC_dir=WaPOR.download_yearly(output_dir, 
                       data='LCC',
                       Startdate='2009-01-01', 
                       Enddate='2010-12-31',
                       latlim=[ymin-0.5, ymax+0.5], 
                       lonlim=[xmin-0.5, xmax+0.5],
                       level=1, 
                       )
# Out:
# Download WaPOR Level 1 monthly PCP data for the period 2009-01-01 till 20010-12-31
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
#
# Download WaPOR Level 1 monthly AETI data for the period 2009-01-01 till 2010-12-31
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
#
# Download WaPOR Level 1 yearly LCC data for the period 2009-01-01 till 2010-12-31
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
